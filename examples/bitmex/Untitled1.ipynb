# %%
import pandas as pd

# %%
store = Arctic('localhost')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-dbdf90b6daf5> in <module>()
# ----> 1 store = Arctic('localhost')
#
# NameError: name 'Arctic' is not defined

# %%
import arctic

# %%
from arctic import Arctic

# %%
store = Arctic('localhost')

# %%
store.initialize_library('crypto')
# Out:
# Library created, but couldn't enable sharding: no such command: 'enablesharding', bad cmd: '{ enablesharding: "arctic", lsid: { id: UUID("aea24b4d-5209-4a5c-8b9b-82d59823691c") }, $db: "admin", $readPreference: { mode: "primaryPreferred" } }'. This is OK if you're not 'admin'

# %%
library = store['crypto']

# %%
item = library.read('XBTUSD')

# %%
xbtusd = item.data

# %%
print (len(xbtusd))
# Out:
# 100

# %%
df['change'] = df['close'].diff()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-f156b616eda8> in <module>()
# ----> 1 df['change'] = df['close'].diff()
#
# NameError: name 'df' is not defined

# %%
xbtusd
# Out:
# [{'timestamp': '2019-07-23T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10591.5,
#   'high': 10685,
#   'low': 10057,
#   'close': 10320.5,
#   'trades': 837467,
#   'volume': 3129671215,
#   'vwap': 10390.6899,
#   'lastSize': 890,
#   'turnover': 30120885360935,
#   'homeNotional': 301208.85360934655,
#   'foreignNotional': 3129671215},
#  {'timestamp': '2019-07-24T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10320.5,
#   'high': 10320.5,
#   'low': 9803,
#   'close': 9844,
#   'trades': 930306,
#   'volume': 3483479222,
#   'vwap': 10035.1229,
#   'lastSize': 5000,
#   'turnover': 34714467039288,
#   'homeNotional': 347144.67039287736,
#   'foreignNotional': 3483479222},
#  {'timestamp': '2019-07-25T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 9844,
#   'high': 9920,
#   'low': 9489.5,
#   'close': 9773,
#   'trades': 869754,
#   'volume': 3473045950,
#   'vwap': 9697.4399,
#   'lastSize': 119,
#   'turnover': 35814602292290,
#   'homeNotional': 358146.0229228979,
#   'foreignNotional': 3473045950},
#  {'timestamp': '2019-07-26T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 9773,
#   'high': 10185,
#   'low': 9740,
#   'close': 9871.5,
#   'trades': 652191,
#   'volume': 2410973560,
#   'vwap': 10016.0256,
#   'lastSize': 3576,
#   'turnover': 24072850350796,
#   'homeNotional': 240728.50350795765,
#   'foreignNotional': 2410973560},
#  {'timestamp': '2019-07-27T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 9871.5,
#   'high': 9900,
#   'low': 9606.5,
#   'close': 9845.5,
#   'trades': 610194,
#   'volume': 2018508690,
#   'vwap': 9769.4412,
#   'lastSize': 1000,
#   'turnover': 20663092089936,
#   'homeNotional': 206630.9208993592,
#   'foreignNotional': 2018508690},
#  {'timestamp': '2019-07-28T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 9845.5,
#   'high': 10300,
#   'low': 9258,
#   'close': 9463.5,
#   'trades': 718864,
#   'volume': 2938517010,
#   'vwap': 9654.3734,
#   'lastSize': 104,
#   'turnover': 30437772159531,
#   'homeNotional': 304377.72159531113,
#   'foreignNotional': 2938517010},
#  {'timestamp': '2019-07-29T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 9463.5,
#   'high': 9748,
#   'low': 9100,
#   'close': 9530.5,
#   'trades': 583402,
#   'volume': 2109224537,
#   'vwap': 9453.5829,
#   'lastSize': 600,
#   'turnover': 22312746992429,
#   'homeNotional': 223127.46992429055,
#   'foreignNotional': 2109224537},
#  {'timestamp': '2019-07-30T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 9530.5,
#   'high': 9734,
#   'low': 9339.5,
#   'close': 9502.5,
#   'trades': 570191,
#   'volume': 2207241220,
#   'vwap': 9533.7973,
#   'lastSize': 400,
#   'turnover': 23152087364170,
#   'homeNotional': 231520.87364170142,
#   'foreignNotional': 2207241220},
#  {'timestamp': '2019-07-31T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 9502.5,
#   'high': 9885,
#   'low': 9375.5,
#   'close': 9592.5,
#   'trades': 578740,
#   'volume': 2294653128,
#   'vwap': 9561.1435,
#   'lastSize': 1,
#   'turnover': 24000953539097,
#   'homeNotional': 240009.53539097097,
#   'foreignNotional': 2294653128},
#  {'timestamp': '2019-08-01T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 9592.5,
#   'high': 10146,
#   'low': 9575,
#   'close': 10088.5,
#   'trades': 684167,
#   'volume': 2646525279,
#   'vwap': 9887.285,
#   'lastSize': 150,
#   'turnover': 26769219773785,
#   'homeNotional': 267692.1977378528,
#   'foreignNotional': 2646525279},
#  {'timestamp': '2019-08-02T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10088.5,
#   'high': 10499,
#   'low': 9885,
#   'close': 10415.5,
#   'trades': 688022,
#   'volume': 2728317073,
#   'vwap': 10141.9878,
#   'lastSize': 500,
#   'turnover': 26903408323980,
#   'homeNotional': 269034.0832398002,
#   'foreignNotional': 2728317073},
#  {'timestamp': '2019-08-03T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10415.5,
#   'high': 10664,
#   'low': 10325,
#   'close': 10528,
#   'trades': 697719,
#   'volume': 2769210533,
#   'vwap': 10493.1794,
#   'lastSize': 700,
#   'turnover': 26392373999654,
#   'homeNotional': 263923.7399965321,
#   'foreignNotional': 2769210533},
#  {'timestamp': '2019-08-04T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10528,
#   'high': 10926,
#   'low': 10514,
#   'close': 10819.5,
#   'trades': 714275,
#   'volume': 2571478309,
#   'vwap': 10779.3468,
#   'lastSize': 2583,
#   'turnover': 23858017661891,
#   'homeNotional': 238580.17661891715,
#   'foreignNotional': 2571478309},
#  {'timestamp': '2019-08-05T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10819.5,
#   'high': 11095,
#   'low': 10570,
#   'close': 10982,
#   'trades': 780489,
#   'volume': 3154544816,
#   'vwap': 10843.6348,
#   'lastSize': 70,
#   'turnover': 29092876018860,
#   'homeNotional': 290928.7601886039,
#   'foreignNotional': 3154544816},
#  {'timestamp': '2019-08-06T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10982,
#   'high': 11971,
#   'low': 10982,
#   'close': 11814.5,
#   'trades': 1111758,
#   'volume': 5082486227,
#   'vwap': 11655.0117,
#   'lastSize': 1000,
#   'turnover': 43609583843671,
#   'homeNotional': 436095.83843670995,
#   'foreignNotional': 5082486227},
#  {'timestamp': '2019-08-07T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 11814.5,
#   'high': 12340,
#   'low': 11220.5,
#   'close': 11467,
#   'trades': 1145768,
#   'volume': 5716377385,
#   'vwap': 11784.115,
#   'lastSize': 390,
#   'turnover': 48509757511460,
#   'homeNotional': 485097.5751146042,
#   'foreignNotional': 5716377385},
#  {'timestamp': '2019-08-08T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 11467,
#   'high': 12170,
#   'low': 11386,
#   'close': 11987.5,
#   'trades': 1162856,
#   'volume': 5276244947,
#   'vwap': 11756.4072,
#   'lastSize': 200,
#   'turnover': 44882853442807,
#   'homeNotional': 448828.53442807804,
#   'foreignNotional': 5276244947},
#  {'timestamp': '2019-08-09T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 11987.5,
#   'high': 12147,
#   'low': 11438.5,
#   'close': 12020,
#   'trades': 1098018,
#   'volume': 4296333405,
#   'vwap': 11800.8025,
#   'lastSize': 2000,
#   'turnover': 36407768399615,
#   'homeNotional': 364077.68399615766,
#   'foreignNotional': 4296333405},
#  {'timestamp': '2019-08-10T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 12020,
#   'high': 12080.5,
#   'low': 11651,
#   'close': 11874,
#   'trades': 902403,
#   'volume': 3230126803,
#   'vwap': 11830.1195,
#   'lastSize': 3000,
#   'turnover': 27304978400437,
#   'homeNotional': 273049.7840043725,
#   'foreignNotional': 3230126803},
#  {'timestamp': '2019-08-11T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 11874,
#   'high': 12000,
#   'low': 11122,
#   'close': 11280,
#   'trades': 757357,
#   'volume': 3027196264,
#   'vwap': 11500.8626,
#   'lastSize': 1500,
#   'turnover': 26324289821600,
#   'homeNotional': 263242.89821600093,
#   'foreignNotional': 3027196264},
#  {'timestamp': '2019-08-12T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 11280,
#   'high': 11596.5,
#   'low': 11072.5,
#   'close': 11531.5,
#   'trades': 584767,
#   'volume': 2097017864,
#   'vwap': 11366.2196,
#   'lastSize': 15000,
#   'turnover': 18450147178219,
#   'homeNotional': 184501.47178219422,
#   'foreignNotional': 2097017864},
#  {'timestamp': '2019-08-13T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 11531.5,
#   'high': 11555,
#   'low': 11222.5,
#   'close': 11395.5,
#   'trades': 551516,
#   'volume': 1710409465,
#   'vwap': 11396.0114,
#   'lastSize': 40,
#   'turnover': 15009383908890,
#   'homeNotional': 150093.8390889022,
#   'foreignNotional': 1710409465},
#  {'timestamp': '2019-08-14T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 11395.5,
#   'high': 11458,
#   'low': 10758.5,
#   'close': 10858.5,
#   'trades': 733009,
#   'volume': 3094724371,
#   'vwap': 11066.8437,
#   'lastSize': 1,
#   'turnover': 27964481567697,
#   'homeNotional': 279644.8156769717,
#   'foreignNotional': 3094724371},
#  {'timestamp': '2019-08-15T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10858.5,
#   'high': 10862,
#   'low': 9913,
#   'close': 10025,
#   'trades': 1041723,
#   'volume': 4998265897,
#   'vwap': 10404.7446,
#   'lastSize': 96677,
#   'turnover': 48040355042909,
#   'homeNotional': 480403.55042908055,
#   'foreignNotional': 4998265897},
#  {'timestamp': '2019-08-16T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10025,
#   'high': 10438,
#   'low': 9475.5,
#   'close': 10290.5,
#   'trades': 1275672,
#   'volume': 6162430723,
#   'vwap': 9949.2588,
#   'lastSize': 70,
#   'turnover': 61944485488857,
#   'homeNotional': 619444.8548885671,
#   'foreignNotional': 6162430723},
#  {'timestamp': '2019-08-17T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10290.5,
#   'high': 10530,
#   'low': 9725,
#   'close': 10350.5,
#   'trades': 1195342,
#   'volume': 5322247302,
#   'vwap': 10149.1931,
#   'lastSize': 17794,
#   'turnover': 52444796071800,
#   'homeNotional': 524447.9607179932,
#   'foreignNotional': 5322247302},
#  {'timestamp': '2019-08-18T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10350.5,
#   'high': 10475.5,
#   'low': 9964.5,
#   'close': 10204,
#   'trades': 769018,
#   'volume': 2469271372,
#   'vwap': 10259.567,
#   'lastSize': 31,
#   'turnover': 24068294518650,
#   'homeNotional': 240682.94518649648,
#   'foreignNotional': 2469271372},
#  {'timestamp': '2019-08-19T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10204,
#   'high': 10520,
#   'low': 10061,
#   'close': 10318,
#   'trades': 637697,
#   'volume': 2132196783,
#   'vwap': 10317.7879,
#   'lastSize': 2348,
#   'turnover': 20665693544764,
#   'homeNotional': 206656.93544763845,
#   'foreignNotional': 2132196783},
#  {'timestamp': '2019-08-20T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10318,
#   'high': 10942,
#   'low': 10268,
#   'close': 10925,
#   'trades': 712451,
#   'volume': 2816151521,
#   'vwap': 10657.5722,
#   'lastSize': 5,
#   'turnover': 26425355705465,
#   'homeNotional': 264253.5570546528,
#   'foreignNotional': 2816151521},
#  {'timestamp': '2019-08-21T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10925,
#   'high': 10959.5,
#   'low': 10554.5,
#   'close': 10773.5,
#   'trades': 694790,
#   'volume': 2741966202,
#   'vwap': 10735.3731,
#   'lastSize': 900,
#   'turnover': 25543706010792,
#   'homeNotional': 255437.06010792163,
#   'foreignNotional': 2741966202},
#  {'timestamp': '2019-08-22T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10773.5,
#   'high': 10807,
#   'low': 9855,
#   'close': 10129,
#   'trades': 887857,
#   'volume': 4151993497,
#   'vwap': 10168.8021,
#   'lastSize': 1135,
#   'turnover': 40834629997058,
#   'homeNotional': 408346.2999705806,
#   'foreignNotional': 4151993497},
#  {'timestamp': '2019-08-23T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10129,
#   'high': 10230,
#   'low': 9744,
#   'close': 10104.5,
#   'trades': 813560,
#   'volume': 3203858195,
#   'vwap': 10001.0001,
#   'lastSize': 87,
#   'turnover': 32037974146684,
#   'homeNotional': 320379.74146684137,
#   'foreignNotional': 3203858195},
#  {'timestamp': '2019-08-24T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10104.5,
#   'high': 10463,
#   'low': 10042,
#   'close': 10401.5,
#   'trades': 648695,
#   'volume': 2333731786,
#   'vwap': 10258.5146,
#   'lastSize': 2002,
#   'turnover': 22750410330735,
#   'homeNotional': 227504.10330734882,
#   'foreignNotional': 2333731786},
#  {'timestamp': '2019-08-25T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10401.5,
#   'high': 10423.5,
#   'low': 9850,
#   'close': 10136,
#   'trades': 665317,
#   'volume': 2605988158,
#   'vwap': 10097.9501,
#   'lastSize': 3040,
#   'turnover': 25808306312344,
#   'homeNotional': 258083.06312343953,
#   'foreignNotional': 2605988158},
#  {'timestamp': '2019-08-26T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10136,
#   'high': 10369,
#   'low': 9875,
#   'close': 10135.5,
#   'trades': 748253,
#   'volume': 2557057170,
#   'vwap': 10099.9899,
#   'lastSize': 18000,
#   'turnover': 25318615613968,
#   'homeNotional': 253186.15613967588,
#   'foreignNotional': 2557057170},
#  {'timestamp': '2019-08-27T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10135.5,
#   'high': 10805,
#   'low': 10137,
#   'close': 10369,
#   'trades': 840840,
#   'volume': 3095112179,
#   'vwap': 10382.0598,
#   'lastSize': 3872,
#   'turnover': 29814209481058,
#   'homeNotional': 298142.09481057216,
#   'foreignNotional': 3095112179},
#  {'timestamp': '2019-08-28T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10369,
#   'high': 10384,
#   'low': 10025,
#   'close': 10176,
#   'trades': 887673,
#   'volume': 2440006950,
#   'vwap': 10163.6345,
#   'lastSize': 900,
#   'turnover': 24008762995280,
#   'homeNotional': 240087.6299528006,
#   'foreignNotional': 2440006950},
#  {'timestamp': '2019-08-29T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10176,
#   'high': 10315,
#   'low': 9497.5,
#   'close': 9701.5,
#   'trades': 1020838,
#   'volume': 3514832496,
#   'vwap': 9967.1085,
#   'lastSize': 200,
#   'turnover': 35264879281176,
#   'homeNotional': 352648.7928117565,
#   'foreignNotional': 3514832496},
#  {'timestamp': '2019-08-30T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 9701.5,
#   'high': 9702,
#   'low': 9321,
#   'close': 9491.5,
#   'trades': 822146,
#   'volume': 2455401317,
#   'vwap': 9493.9713,
#   'lastSize': 1674,
#   'turnover': 25862887331570,
#   'homeNotional': 258628.87331570295,
#   'foreignNotional': 2455401317},
#  {'timestamp': '2019-08-31T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 9491.5,
#   'high': 9690,
#   'low': 9341.5,
#   'close': 9574,
#   'trades': 591205,
#   'volume': 1921000276,
#   'vwap': 9531.9798,
#   'lastSize': 2012,
#   'turnover': 20154020422451,
#   'homeNotional': 201540.20422451035,
#   'foreignNotional': 1921000276},
#  {'timestamp': '2019-09-01T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 9574,
#   'high': 9703.5,
#   'low': 9434.5,
#   'close': 9602.5,
#   'trades': 473214,
#   'volume': 1385068208,
#   'vwap': 9582.2154,
#   'lastSize': 1,
#   'turnover': 14455100382558,
#   'homeNotional': 144551.00382558108,
#   'foreignNotional': 1385068208},
#  {'timestamp': '2019-09-02T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 9602.5,
#   'high': 9844,
#   'low': 9531,
#   'close': 9771.5,
#   'trades': 438608,
#   'volume': 1378560767,
#   'vwap': 9661.8357,
#   'lastSize': 4236,
#   'turnover': 14268243231388,
#   'homeNotional': 142682.43231388013,
#   'foreignNotional': 1378560767},
#  {'timestamp': '2019-09-03T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 9771.5,
#   'high': 10500,
#   'low': 9745.5,
#   'close': 10391,
#   'trades': 728838,
#   'volume': 3287239990,
#   'vwap': 10080.6452,
#   'lastSize': 5000,
#   'turnover': 32611968827932,
#   'homeNotional': 326119.68827931926,
#   'foreignNotional': 3287239990},
#  {'timestamp': '2019-09-04T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10391,
#   'high': 10783,
#   'low': 10300,
#   'close': 10630,
#   'trades': 821807,
#   'volume': 3730362374,
#   'vwap': 10557.4324,
#   'lastSize': 2000,
#   'turnover': 35335444547601,
#   'homeNotional': 353354.44547600666,
#   'foreignNotional': 3730362374},
#  {'timestamp': '2019-09-05T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10630,
#   'high': 10879,
#   'low': 10380.5,
#   'close': 10580.5,
#   'trades': 849000,
#   'volume': 3667564531,
#   'vwap': 10576.4146,
#   'lastSize': 1,
#   'turnover': 34679778784269,
#   'homeNotional': 346797.78784268704,
#   'foreignNotional': 3667564531},
#  {'timestamp': '2019-09-06T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10580.5,
#   'high': 10683,
#   'low': 10454,
#   'close': 10586,
#   'trades': 711100,
#   'volume': 2406367926,
#   'vwap': 10570.8245,
#   'lastSize': 5767,
#   'turnover': 22764622093977,
#   'homeNotional': 227646.22093976295,
#   'foreignNotional': 2406367926},
#  {'timestamp': '2019-09-07T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10586,
#   'high': 10968,
#   'low': 10205,
#   'close': 10310.5,
#   'trades': 937074,
#   'volume': 4202998455,
#   'vwap': 10628.122,
#   'lastSize': 1588,
#   'turnover': 39546643092549,
#   'homeNotional': 395466.43092549115,
#   'foreignNotional': 4202998455},
#  {'timestamp': '2019-09-08T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10310.5,
#   'high': 10576,
#   'low': 10308,
#   'close': 10492.5,
#   'trades': 547178,
#   'volume': 1719270081,
#   'vwap': 10442.7736,
#   'lastSize': 140,
#   'turnover': 16465010604393,
#   'homeNotional': 164650.10604392638,
#   'foreignNotional': 1719270081},
#  {'timestamp': '2019-09-09T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10492.5,
#   'high': 10599,
#   'low': 10252.5,
#   'close': 10402,
#   'trades': 510768,
#   'volume': 1834957860,
#   'vwap': 10437.3239,
#   'lastSize': 4422,
#   'turnover': 17581931890584,
#   'homeNotional': 175819.31890584057,
#   'foreignNotional': 1834957860},
#  {'timestamp': '2019-09-10T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10402,
#   'high': 10571,
#   'low': 10090,
#   'close': 10318,
#   'trades': 829102,
#   'volume': 3563034952,
#   'vwap': 10292.3014,
#   'lastSize': 26752,
#   'turnover': 34620814653593,
#   'homeNotional': 346208.14653592685,
#   'foreignNotional': 3563034952},
#  {'timestamp': '2019-09-11T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10318,
#   'high': 10394,
#   'low': 9892,
#   'close': 10102.5,
#   'trades': 675497,
#   'volume': 2461539814,
#   'vwap': 10171.9052,
#   'lastSize': 50,
#   'turnover': 24201299279998,
#   'homeNotional': 242012.99279998033,
#   'foreignNotional': 2461539814},
#  {'timestamp': '2019-09-12T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10102.5,
#   'high': 10280,
#   'low': 9850,
#   'close': 10166,
#   'trades': 759281,
#   'volume': 2768292719,
#   'vwap': 10058.3384,
#   'lastSize': 2500,
#   'turnover': 27523570480928,
#   'homeNotional': 275235.7048092812,
#   'foreignNotional': 2768292719},
#  {'timestamp': '2019-09-13T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10166,
#   'high': 10469.5,
#   'low': 10032,
#   'close': 10433.5,
#   'trades': 672332,
#   'volume': 2461241420,
#   'vwap': 10255.3584,
#   'lastSize': 100,
#   'turnover': 24000405951934,
#   'homeNotional': 240004.05951933263,
#   'foreignNotional': 2461241420},
#  {'timestamp': '2019-09-14T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10433.5,
#   'high': 10458.5,
#   'low': 10161.5,
#   'close': 10370,
#   'trades': 583263,
#   'volume': 1974996040,
#   'vwap': 10310.3413,
#   'lastSize': 1,
#   'turnover': 19157237942173,
#   'homeNotional': 191572.3794217288,
#   'foreignNotional': 1974996040},
#  {'timestamp': '2019-09-15T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10370,
#   'high': 10447.5,
#   'low': 10221,
#   'close': 10364,
#   'trades': 526045,
#   'volume': 1692697317,
#   'vwap': 10354.1106,
#   'lastSize': 110,
#   'turnover': 16349485672166,
#   'homeNotional': 163494.85672165905,
#   'foreignNotional': 1692697317},
#  {'timestamp': '2019-09-16T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10364,
#   'high': 10387,
#   'low': 10260,
#   'close': 10314,
#   'trades': 374645,
#   'volume': 1114698246,
#   'vwap': 10317.7879,
#   'lastSize': 1000,
#   'turnover': 10804722100026,
#   'homeNotional': 108047.22100025989,
#   'foreignNotional': 1114698246},
#  {'timestamp': '2019-09-17T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10314,
#   'high': 10391.5,
#   'low': 10066,
#   'close': 10268,
#   'trades': 547489,
#   'volume': 2217227507,
#   'vwap': 10236.4623,
#   'lastSize': 1,
#   'turnover': 21661571906993,
#   'homeNotional': 216615.7190699265,
#   'foreignNotional': 2217227507},
#  {'timestamp': '2019-09-18T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10268,
#   'high': 10284,
#   'low': 10137.5,
#   'close': 10184.5,
#   'trades': 541823,
#   'volume': 1862503320,
#   'vwap': 10217.6356,
#   'lastSize': 1,
#   'turnover': 18229202183458,
#   'homeNotional': 182292.02183457796,
#   'foreignNotional': 1862503320},
#  {'timestamp': '2019-09-19T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10184.5,
#   'high': 10262.5,
#   'low': 10075,
#   'close': 10163,
#   'trades': 445820,
#   'volume': 1517895773,
#   'vwap': 10190.5635,
#   'lastSize': 195,
#   'turnover': 14896267445667,
#   'homeNotional': 148962.67445667097,
#   'foreignNotional': 1517895773},
#  {'timestamp': '2019-09-20T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10163,
#   'high': 10442,
#   'low': 9567,
#   'close': 10282.5,
#   'trades': 719836,
#   'volume': 3368765552,
#   'vwap': 9980.0399,
#   'lastSize': 1758,
#   'turnover': 33756814791090,
#   'homeNotional': 337568.14791089884,
#   'foreignNotional': 3368765552},
#  {'timestamp': '2019-09-21T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10282.5,
#   'high': 10319.5,
#   'low': 10061,
#   'close': 10175.5,
#   'trades': 493206,
#   'volume': 1608962567,
#   'vwap': 10176.0456,
#   'lastSize': 938,
#   'turnover': 15811943289814,
#   'homeNotional': 158119.43289813655,
#   'foreignNotional': 1608962567},
#  {'timestamp': '2019-09-22T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10175.5,
#   'high': 10176,
#   'low': 9902.5,
#   'close': 9975.5,
#   'trades': 542071,
#   'volume': 1585453842,
#   'vwap': 10023.053,
#   'lastSize': 149,
#   'turnover': 15819133125100,
#   'homeNotional': 158191.33125099956,
#   'foreignNotional': 1585453842},
#  {'timestamp': '2019-09-23T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 9975.5,
#   'high': 10100,
#   'low': 9840.5,
#   'close': 10026,
#   'trades': 608281,
#   'volume': 1698994877,
#   'vwap': 9977.0528,
#   'lastSize': 972,
#   'turnover': 17029710833201,
#   'homeNotional': 170297.1083320107,
#   'foreignNotional': 1698994877},
#  {'timestamp': '2019-09-24T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 10026,
#   'high': 10049.5,
#   'low': 9603.5,
#   'close': 9686,
#   'trades': 756204,
#   'volume': 2783512865,
#   'vwap': 9829.942,
#   'lastSize': 72,
#   'turnover': 28317421769855,
#   'homeNotional': 283174.21769855043,
#   'foreignNotional': 2783512865},
#  {'timestamp': '2019-09-25T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 9686,
#   'high': 9779.5,
#   'low': 8012,
#   'close': 8533.5,
#   'trades': 1252875,
#   'volume': 6725380596,
#   'vwap': 8958.9679,
#   'lastSize': 1,
#   'turnover': 75073380557611,
#   'homeNotional': 750733.8055761161,
#   'foreignNotional': 6725380596},
#  {'timestamp': '2019-09-26T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8533.5,
#   'high': 8748,
#   'low': 8215,
#   'close': 8430,
#   'trades': 1051314,
#   'volume': 4045724084,
#   'vwap': 8426.0195,
#   'lastSize': 26,
#   'turnover': 48016952017467,
#   'homeNotional': 480169.52017467667,
#   'foreignNotional': 4045724084},
#  {'timestamp': '2019-09-27T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8430,
#   'high': 8466,
#   'low': 7736,
#   'close': 8054,
#   'trades': 990231,
#   'volume': 4010130760,
#   'vwap': 8112.2739,
#   'lastSize': 1000,
#   'turnover': 49435890157440,
#   'homeNotional': 494358.90157440363,
#   'foreignNotional': 4010130760},
#  {'timestamp': '2019-09-28T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8054,
#   'high': 8265,
#   'low': 7860,
#   'close': 8189,
#   'trades': 758451,
#   'volume': 2456542220,
#   'vwap': 8032.7737,
#   'lastSize': 3,
#   'turnover': 30583258180557,
#   'homeNotional': 305832.5818055708,
#   'foreignNotional': 2456542220},
#  {'timestamp': '2019-09-29T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8189,
#   'high': 8400,
#   'low': 8015,
#   'close': 8207,
#   'trades': 594604,
#   'volume': 1727544035,
#   'vwap': 8159.9347,
#   'lastSize': 100,
#   'turnover': 21172320103072,
#   'homeNotional': 211723.2010307226,
#   'foreignNotional': 1727544035},
#  {'timestamp': '2019-09-30T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8207,
#   'high': 8238.5,
#   'low': 7900,
#   'close': 8054,
#   'trades': 599397,
#   'volume': 1822807833,
#   'vwap': 8042.4642,
#   'lastSize': 5309,
#   'turnover': 22665752085181,
#   'homeNotional': 226657.52085180953,
#   'foreignNotional': 1822807833},
#  {'timestamp': '2019-10-01T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8054,
#   'high': 8344.5,
#   'low': 7688,
#   'close': 8299.5,
#   'trades': 866067,
#   'volume': 3373793628,
#   'vwap': 8032.1285,
#   'lastSize': 9411,
#   'turnover': 42004040309207,
#   'homeNotional': 420040.40309207095,
#   'foreignNotional': 3373793628},
#  {'timestamp': '2019-10-02T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8299.5,
#   'high': 8532,
#   'low': 8200,
#   'close': 8314,
#   'trades': 806274,
#   'volume': 2754664272,
#   'vwap': 8369.6016,
#   'lastSize': 1,
#   'turnover': 32915179206234,
#   'homeNotional': 329151.79206234275,
#   'foreignNotional': 2754664272},
#  {'timestamp': '2019-10-03T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8314,
#   'high': 8386,
#   'low': 8173,
#   'close': 8377.5,
#   'trades': 554557,
#   'volume': 1537659900,
#   'vwap': 8258.3203,
#   'lastSize': 1,
#   'turnover': 18620010344861,
#   'homeNotional': 186200.10344861198,
#   'foreignNotional': 1537659900},
#  {'timestamp': '2019-10-04T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8377.5,
#   'high': 8420.5,
#   'low': 8070,
#   'close': 8240.5,
#   'trades': 583640,
#   'volume': 1946444699,
#   'vwap': 8216.2517,
#   'lastSize': 1,
#   'turnover': 23692109626839,
#   'homeNotional': 236921.0962683926,
#   'foreignNotional': 1946444699},
#  {'timestamp': '2019-10-05T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8240.5,
#   'high': 8243,
#   'low': 8020,
#   'close': 8154.5,
#   'trades': 598438,
#   'volume': 1680861122,
#   'vwap': 8139.3456,
#   'lastSize': 1000,
#   'turnover': 20651413717721,
#   'homeNotional': 206514.1371772142,
#   'foreignNotional': 1680861122},
#  {'timestamp': '2019-10-06T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8154.5,
#   'high': 8200,
#   'low': 8022,
#   'close': 8146.5,
#   'trades': 462778,
#   'volume': 1247070981,
#   'vwap': 8101.7581,
#   'lastSize': 3370,
#   'turnover': 15393124221455,
#   'homeNotional': 153931.24221455227,
#   'foreignNotional': 1247070981},
#  {'timestamp': '2019-10-07T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8146.5,
#   'high': 8172,
#   'low': 7770,
#   'close': 7861,
#   'trades': 649843,
#   'volume': 2177529708,
#   'vwap': 7953.5513,
#   'lastSize': 349,
#   'turnover': 27379761612971,
#   'homeNotional': 273797.6161297117,
#   'foreignNotional': 2177529708},
#  {'timestamp': '2019-10-08T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 7861,
#   'high': 8307.5,
#   'low': 7765,
#   'close': 8208,
#   'trades': 781365,
#   'volume': 2790485285,
#   'vwap': 8059.3166,
#   'lastSize': 500,
#   'turnover': 34624711467317,
#   'homeNotional': 346247.114673174,
#   'foreignNotional': 2790485285},
#  {'timestamp': '2019-10-09T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8208,
#   'high': 8332.5,
#   'low': 8095.5,
#   'close': 8180,
#   'trades': 564760,
#   'volume': 1775864658,
#   'vwap': 8208.8327,
#   'lastSize': 90838,
#   'turnover': 21635177710940,
#   'homeNotional': 216351.7771094046,
#   'foreignNotional': 1775864658},
#  {'timestamp': '2019-10-10T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8180,
#   'high': 8692,
#   'low': 8111.5,
#   'close': 8587.5,
#   'trades': 731377,
#   'volume': 2918198967,
#   'vwap': 8424.5998,
#   'lastSize': 1,
#   'turnover': 34641459889088,
#   'homeNotional': 346414.5988908817,
#   'foreignNotional': 2918198967},
#  {'timestamp': '2019-10-11T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8587.5,
#   'high': 8662.5,
#   'low': 8466,
#   'close': 8586.5,
#   'trades': 585807,
#   'volume': 1820350604,
#   'vwap': 8556.5158,
#   'lastSize': 4902,
#   'turnover': 21276068180133,
#   'homeNotional': 212760.681801333,
#   'foreignNotional': 1820350604},
#  {'timestamp': '2019-10-12T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8586.5,
#   'high': 8821.5,
#   'low': 8222,
#   'close': 8266,
#   'trades': 711915,
#   'volume': 2840802059,
#   'vwap': 8450.2282,
#   'lastSize': 19000,
#   'turnover': 33619171978773,
#   'homeNotional': 336191.71978773683,
#   'foreignNotional': 2840802059},
#  {'timestamp': '2019-10-13T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8266,
#   'high': 8399.5,
#   'low': 8252,
#   'close': 8305,
#   'trades': 350255,
#   'volume': 914764702,
#   'vwap': 8333.3333,
#   'lastSize': 1000,
#   'turnover': 10977397096564,
#   'homeNotional': 109773.97096564106,
#   'foreignNotional': 914764702},
#  {'timestamp': '2019-10-14T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8305,
#   'high': 8466,
#   'low': 8150,
#   'close': 8278,
#   'trades': 477670,
#   'volume': 1600848345,
#   'vwap': 8345.1556,
#   'lastSize': 5000,
#   'turnover': 19183958143227,
#   'homeNotional': 191839.581432271,
#   'foreignNotional': 1600848345},
#  {'timestamp': '2019-10-15T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8278,
#   'high': 8406,
#   'low': 8221,
#   'close': 8358,
#   'trades': 437998,
#   'volume': 1383917320,
#   'vwap': 8307.7179,
#   'lastSize': 27,
#   'turnover': 16659506402364,
#   'homeNotional': 166595.0640236409,
#   'foreignNotional': 1383917320},
#  {'timestamp': '2019-10-16T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8358,
#   'high': 8420,
#   'low': 8076,
#   'close': 8156,
#   'trades': 513081,
#   'volume': 1833941267,
#   'vwap': 8251.5059,
#   'lastSize': 5000,
#   'turnover': 22226767339434,
#   'homeNotional': 222267.67339434213,
#   'foreignNotional': 1833941267},
#  {'timestamp': '2019-10-17T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8156,
#   'high': 8175,
#   'low': 7912.5,
#   'close': 7995.5,
#   'trades': 471379,
#   'volume': 1714484458,
#   'vwap': 8032.7737,
#   'lastSize': 4804,
#   'turnover': 21344361079863,
#   'homeNotional': 213443.6107986269,
#   'foreignNotional': 1714484458},
#  {'timestamp': '2019-10-18T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 7995.5,
#   'high': 8123,
#   'low': 7937.5,
#   'close': 8070.5,
#   'trades': 451661,
#   'volume': 1379848088,
#   'vwap': 8038.5852,
#   'lastSize': 192,
#   'turnover': 17165570783078,
#   'homeNotional': 171655.70783078167,
#   'foreignNotional': 1379848088},
#  {'timestamp': '2019-10-19T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8070.5,
#   'high': 8112,
#   'low': 7799.5,
#   'close': 7951,
#   'trades': 538095,
#   'volume': 2025413894,
#   'vwap': 7931.4721,
#   'lastSize': 1,
#   'turnover': 25536554247463,
#   'homeNotional': 255365.5424746263,
#   'foreignNotional': 2025413894},
#  {'timestamp': '2019-10-20T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 7951,
#   'high': 8110,
#   'low': 7868,
#   'close': 7960,
#   'trades': 483691,
#   'volume': 1515391394,
#   'vwap': 7967.4926,
#   'lastSize': 2000,
#   'turnover': 19021075121737,
#   'homeNotional': 190210.75121736905,
#   'foreignNotional': 1515391394},
#  {'timestamp': '2019-10-21T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 7960,
#   'high': 8318,
#   'low': 7866,
#   'close': 8233,
#   'trades': 620683,
#   'volume': 2151767217,
#   'vwap': 8068.4202,
#   'lastSize': 4353,
#   'turnover': 26670234535085,
#   'homeNotional': 266702.34535085055,
#   'foreignNotional': 2151767217},
#  {'timestamp': '2019-10-22T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8233,
#   'high': 8357,
#   'low': 8155.5,
#   'close': 8204.5,
#   'trades': 454199,
#   'volume': 1615409161,
#   'vwap': 8228.421,
#   'lastSize': 400,
#   'turnover': 19632089291562,
#   'homeNotional': 196320.89291562475,
#   'foreignNotional': 1615409161},
#  {'timestamp': '2019-10-23T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8204.5,
#   'high': 8313,
#   'low': 7981.5,
#   'close': 8019,
#   'trades': 519118,
#   'volume': 1943310865,
#   'vwap': 8180.6283,
#   'lastSize': 8536,
#   'turnover': 23755186663116,
#   'homeNotional': 237551.86663116163,
#   'foreignNotional': 1943310865},
#  {'timestamp': '2019-10-24T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8019,
#   'high': 8044.5,
#   'low': 7298,
#   'close': 7468,
#   'trades': 688115,
#   'volume': 3184348868,
#   'vwap': 7634.7534,
#   'lastSize': 500,
#   'turnover': 41710829843880,
#   'homeNotional': 417108.29843879596,
#   'foreignNotional': 3184348868},
#  {'timestamp': '2019-10-25T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 7468,
#   'high': 7504.5,
#   'low': 7355,
#   'close': 7424,
#   'trades': 443118,
#   'volume': 1438106601,
#   'vwap': 7439.9226,
#   'lastSize': 5000,
#   'turnover': 19330149275001,
#   'homeNotional': 193301.49275001092,
#   'foreignNotional': 1438106601},
#  {'timestamp': '2019-10-26T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 7424,
#   'high': 8790,
#   'low': 7380.5,
#   'close': 8668,
#   'trades': 959864,
#   'volume': 5046279493,
#   'vwap': 8128.0988,
#   'lastSize': 178,
#   'turnover': 62085103277150,
#   'homeNotional': 620851.0327714992,
#   'foreignNotional': 5046279493},
#  {'timestamp': '2019-10-27T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 8668,
#   'high': 10584.5,
#   'low': 8645,
#   'close': 9264.5,
#   'trades': 1609422,
#   'volume': 8255466579,
#   'vwap': 9416.1959,
#   'lastSize': 500,
#   'turnover': 87677285539664,
#   'homeNotional': 876772.8553966398,
#   'foreignNotional': 8255466579},
#  {'timestamp': '2019-10-28T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 9264.5,
#   'high': 9832.5,
#   'low': 9105,
#   'close': 9556,
#   'trades': 1109775,
#   'volume': 4626756280,
#   'vwap': 9489.4667,
#   'lastSize': 1000,
#   'turnover': 48760238894703,
#   'homeNotional': 487602.38894702634,
#   'foreignNotional': 4626756280},
#  {'timestamp': '2019-10-29T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 9556,
#   'high': 9944,
#   'low': 9167,
#   'close': 9226,
#   'trades': 926100,
#   'volume': 3712381533,
#   'vwap': 9512.0327,
#   'lastSize': 1000,
#   'turnover': 39031350949968,
#   'homeNotional': 390313.50949968206,
#   'foreignNotional': 3712381533},
#  {'timestamp': '2019-10-30T00:00:00.000Z',
#   'symbol': 'XBTUSD',
#   'open': 9226,
#   'high': 9565.5,
#   'low': 9058,
#   'close': 9438,
#   'trades': 815914,
#   'volume': 3366567658,
#   'vwap': 9384.3844,
#   'lastSize': 195,
#   'turnover': 35876947845708,
#   'homeNotional': 358769.47845708206,
#   'foreignNotional': 3366567658}]

# %%
xbtusd.data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-24854f3a4052> in <module>()
# ----> 1 xbtusd.data
#
# AttributeError: 'list' object has no attribute 'data'
